# %% [markdown]
# <a href="https://colab.research.google.com/github/lokasenna9312/AIFFEL_quest_cr/blob/main/Python/Quest02/20250110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

f = open("/content/drive/MyDrive/Aiffel/Avengers.txt", 'r')
data = f.read()

#1-1. 모든 문자를 소문자로 변환
lower_data = data.lower()

#1-2. 모든 기호를 제거한다.
t_text = lower_data.replace("-", "")
t_text = t_text.replace(".", "") #문장 마지막에 있는 마침표는 줄바꿈과 합쳐졌을 수 있음
t_text = t_text.replace(",", "")
t_text = t_text.replace("?", "")
t_text = t_text.replace("!", "")
t_text = t_text.replace("'s", " is")
t_text = t_text.replace("n't", " not")
t_text = t_text.replace("'m", " am")
t_text = t_text.replace("'re", " are")
t_text = t_text.replace("'ll", " will")
t_text = t_text.replace("'d", " would")
t_text = t_text.replace("'ve", " have")
t_text = t_text.replace("\n", "") #나중에 다시 보기

#1-3. 단어 단위로 분리한다.
temp_list = t_text.split(" ")

#2. 각 단어 별 빈도수를 딕셔너리 형태로 저장한다.
t_dict = {} #빈 딕셔너리를 하나 생성한다.
for i in range(0,len(temp_list)): #리스트 요소값 확인
  if temp_list[i] not in t_dict: #만약, 현재 요소 값이 딕셔너리 안에 없다면
    t_dict.update({temp_list[i]:1}) #딕셔너리의 키로 새로 생성하고, 키의 발견 횟수를 1로 저장한다
  else:
    new_cnt = t_dict[temp_list[i]] + 1
    t_dict.update({temp_list[i]:new_cnt}) #새로운 빈도수로 dict 업데이트


#3. 딕셔너리를 빈도수순으로 내림차순 정렬하고, 정렬 순서대로 정수 인덱스를 부여한다.
t_dict_sorted = sorted(t_dict,key=lambda x:t_dict[x], reverse=True)
print(t_dict_sorted)

#4. 텍스트를 input()으로 입력받아서 정수를 return하는 함수를 만든다.
text = input("텍스트 입력: ")
t_text = text.split(" ")
result = []
for t in t_text:
  result_rank = t_dict_sorted.index(t)+1
  result.append(result_rank)
print(result)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['the', 'is', 'you', 'to', 'i', 'a', 'not', 'that', 'it', 'of', 'are', 'we', 'have', 'on', 'in', 'do', 'he', 'and', 'for', 'this', 'what', 'be', 'am', 'will', 'did', 'know', 'was', 'me', 'out', 'get', 'your', 'need', 'no', 'my', 'like', 'got', 'they', 'all', 'up', 'can', 'an', 'tesseract', 'his', 'with', 'loki', 'gonna', 'would', 'about', 'if', 'think', 'just', 'come', 'here', 'there', 'from', 'them', 'him', 'how', 'stark', 'should', 'as', 'world', 'so', 'but', 'has', 'put', 'ca', 'us', 'right', 'one', 'why', 'our', 'back', 'well', 'were', 'down', 'tell', 'does', 'fury', 'now', 'guy', 'at', 'off', 'who', 'where', 'take', 'man', 'could', 'only', 'made', 'mean', 'want', 'wanna', 'way', 'people', 'let', 'go', 'time', 'other', 'everything', 'find', 'some', 'good', 'little', 'really', 'power', 'see', 'cube', 'say', 'been', 'work', 'into', 'energy', 'when', 'make', 'every', 'anything', 'agent', 'thing', 'too', 'more', 'wants', 'war', 'something', 'shield', 'gotta', 'never', 'selvig', 'doctor', 'barton', 'end', 'still', 'lot', 'by', 'thought', 'than', 'had', 'call', 'doing', 'knows', 'engine', 'shut', 'long', 'may', 'might', 'or', 'any', 'asgard', 'portal', 'these', 'men', 'keep', 'sorry', 'very', 'point', 'then', 'banner', 'yeah', 'suit', 'until', 'things', 'kind', 'pretty', 'give', 'look', 'hold', 'big', 'away', 'stop', 'ever', 'over', 'avengers', 'seen', 'around', 'going', 'stay', 'love', 'much', 'army', 'working', 'sir', 'even', 'next', 'sure', 'she', 'turn', 'close', 'better', 'before', 'leave', 'first', 'try', 'needs', 'yourself', 'percent', 'nothing', 'play', 'dr', 'earth', 'king', 'coming', 'hit', 'yes', 'its', 'ready', 'force', 'control', 'though', 'space', 'far', 'gamma', 'open', 'life', 'means', '', 'many', 'true', 'miss', 'lost', 'those', 'wipe', 'thor', 'team', 'enough', 'coulson', 'phil', 'name', 'hard', 'new', 'captain', 'romanoff', 'once', 'remember', 'guys', 'together', 'none', 'their', 'run', 'youi', 'fight', 'lead', 'humans', 'maybe', 'phase', '2', 'director', 'mei', 'seeing', 'place', 'two', 'without', 'feel', 'listen', 'blow', 'takes', 'talk', 'god', 'spy', 'start', 'kill', 'mewe', 'seems', 'says', 'after', 'use', 'line', 'exactly', 'oh', 'trying', 'secret', 'took', 'bring', 'already', 'rest', 'youyou', 'become', 'self', 'actually', 'came', 'tower', 'twelve', 'mr', 'which', 'last', 'used', 'while', 'huge', 'against', 'yet', 'thank', 'eyes', 'always', 'another', 'plan', 'done', 'wo', 'through', 'because', 'hulk', 'wait', 'three', 'okay', 'perimeter', 'chitauri', 'bad', 'read', 'pull', 'test', 'room', 'itself', 'everyone', 'supposed', 'soon', 'please', 'course', 'glorious', 'step', 'free', 'great', 'peace', 'hundred', 'copy', 'looking', 'running', 'father', 'wake', 'hell', 'whole', 'meand', 'kept', 'youand', 'year', 'break', 'monster', 'told', 'controlyou', 'intelligence', 'security', 'won', 'under', 'save', 'called', 'jarvis', 'being', 'tony', 'alright', 'whatever', 'having', 'moved', 'meet', 'hope', 'old', 'scepter', 'full', 'beyond', 'pain', 'word', 'care', 'worse', 'lets', 'thanks', 'asking', 'hands', 'few', 'show', 'couple', 'location', 'move', 'attack', 'son', 'sent', 'again', 'idea', 'built', 'makes', 'building', 'erik', 'someone', 'lose', 'understand', 'source', 'focused', 'armor', 'taking', 'changed', 'fall', 'red', 'change', 'same', 'slow', 'form', 'needed', 'anybody', 'heroes', 'believing', 'soldier', 'council', 'human', 'wield', 'universe', 'problem', 'levels', 'clear', 'half', 'safe', 'act', 'certain', 'funny', 'level', 'prepared', 'low', 'gave', 'eye', 'set', 'brother', 'quarrel', 'planning', 'glad', 'freedom', 'feet', 'raw', 'odin', 'minutes', 'goes', 'track', 'calli', 'living', 'roger', 'himi', 'handle', 'ask', 'giving', 'everythingi', 'heat', 'paid', 'banneryou', 'stress', 'brought', 'city', 'youbut', 'noyou', 'potential', 'planet', 'signature', 'radiation', 'lying', 'wanted', 'dowhy', 'dealing', 'saying', 'lokihe', 'worlds', 'focusing', 'response', 'initiative', 'leaving', 'believe', 'pushthey', ' ...
# 텍스트 입력: the
# [1]

# %%
from google.colab import drive
drive.mount('/content/drive')
